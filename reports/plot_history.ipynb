# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the training history from the CSV file

# %%
# Extract the metrics from the DataFrame
history_df = pd.read_csv('training_history_model1_1.csv')
epochs = range(1, len(history_df) + 1)
training_loss = history_df['loss']
validation_loss = history_df['val_loss']
plt.figure(figsize=(12, 5))
# Loss Plot
plt.subplot(1, 2, 1)
plt.ylim(.50, .65) 
plt.plot(epochs, training_loss, label='Training Loss')
plt.plot(epochs, validation_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
# Extract the metrics from the DataFrame
history_df = pd.read_csv('training_history_model1_2.csv')
epochs = range(1, len(history_df) + 1)
training_loss = history_df['loss']
validation_loss = history_df['val_loss']
plt.figure(figsize=(12, 5))

# Loss Plot
plt.subplot(1, 2, 1)
plt.ylim(.50, .65) 
plt.plot(epochs, training_loss, label='Training Loss')
plt.plot(epochs, validation_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
# Extract the metrics from the DataFrame
history_df = pd.read_csv('training_history_model1_3.csv')
epochs = range(1, len(history_df) + 1)
training_loss = history_df['loss']
validation_loss = history_df['val_loss']
plt.figure(figsize=(12, 5))

# Loss Plot
plt.subplot(1, 2, 1)
plt.ylim(.50, .65) 
plt.plot(epochs, training_loss, label='Training Loss')
plt.plot(epochs, validation_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\reports\plot_history.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/reports/plot_history.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Extract the metrics from the DataFrame
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/reports/plot_history.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> history_df = pd.read_csv('training_history_model1_3.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/reports/plot_history.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> epochs = range(1, len(history_df) + 1)
#       <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/reports/plot_history.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> training_loss = history_df['loss']
#
# ...
