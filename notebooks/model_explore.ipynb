# %%
from tensorflow import keras

# %%
model = keras.models.load_model ('../trained_models/model1/m1_train5')

# %%
model.summary()
# Out:
# Model: "model1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Group_NN (Sequential)       (None, 16)                19600
#
#  Technique_NN (Sequential)   (None, 16)                71312
#
#  dot (Dot)                   multiple                  0
#
# =================================================================
# Total params: 90,912
# Trainable params: 90,912
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.Technique_NN.summary()
# Out:
# Model: "Technique_NN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                53632
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 64)                4160
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  output_NN (Dense)           (None, 16)                1040
#
# =================================================================
# Total params: 71,312
# Trainable params: 71,312
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.Group_NN.layers
# Out:
# [<keras.layers.core.dense.Dense at 0x230329c9710>,
#  <keras.layers.regularization.dropout.Dropout at 0x23032a3ddd0>,
#  <keras.layers.core.dense.Dense at 0x23032a5f4d0>,
#  <keras.layers.regularization.dropout.Dropout at 0x23033dd0310>,
#  <keras.layers.core.dense.Dense at 0x23033dd0ed0>,
#  <keras.layers.regularization.dropout.Dropout at 0x23033dd2090>,
#  <keras.layers.core.dense.Dense at 0x23033dd2b90>,
#  <keras.layers.regularization.dropout.Dropout at 0x23033dd3ed0>,
#  <keras.layers.core.dense.Dense at 0x23033ddcb50>,
#  <keras.layers.regularization.dropout.Dropout at 0x23033dddfd0>,
#  <keras.layers.core.dense.Dense at 0x23033ddec10>]

# %%
print (model.Group_NN.layers[-1].kernel_initializer)
# Out:
# <keras.initializers.initializers.GlorotUniform object at 0x000001380B1FC190>

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model.Group_NN, show_shapes=True)

# %%
model2 = keras.models.Sequential (
    [keras.layers.Dense (8, activation= 'relu'),
     keras.layers.Dropout (rate = 0.1)]
)

# %%
model2.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\model_explore.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/notebooks/model_explore.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> model2.summary()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\engine\training.py:3229, in Model.summary(self, line_length, positions, print_fn, expand_nested, show_trainable, layer_range)
#    3198 """Prints a string summary of the network.
#    3199
#    3200 Args:
#    (...)
#    3226     ValueError: if `summary()` is called before the model is built.
#    3227 """
#    3228 if not self.built:
# -> 3229     raise ValueError(
#    3230         "This model has not yet been built. "
#    3231         "Build the model first by calling `build()` or by calling "
#    3232         "the model on a batch of data."
#    3233     )
#    3234 layer_utils.print_summary(
#    3235     self,
#    3236     line_length=line_length,
#    (...)
#    3241     layer_range=layer_range,
#    3242 )
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or by calling the model on a batch of data.
