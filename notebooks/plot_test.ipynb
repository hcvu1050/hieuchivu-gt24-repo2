# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.grid_plot_history_with_config (model_name= 'model1', folder_name = 'model1_single_train',labels = ['loss', 'val_loss'], ylims=[0.46, 0.7])
# Out:
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:105: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:105: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:105: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
plotting.multi_line_plot_history (model_name= 'model1', 
                                  folder_name = 'model1_batch3', 
                                  label = 'loss',
                                  hyperparameter = ['model_architecture', 'regularizer_weight'],
                                  ylims=[0.45, 0.6], xlims = [0,100])
