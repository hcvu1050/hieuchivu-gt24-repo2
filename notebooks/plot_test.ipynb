# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.batch_plot_history_with_config (model_name= 'model1', folder_name = 'model1_batch7',labels = ['loss', 'val_loss'], ylims=[0.46, 0.7])
# Out:
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:75: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:75: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:75: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# plotting.batch_plot_loss (model_name= 'model1', folder_name = 'model1_batch2', ylims=[0.45, 0.7])
