# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.batch_plot_loss (model_name= 'model1', folder_name = 'model1_single_train')
