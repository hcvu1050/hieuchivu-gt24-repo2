# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.grid_plot_history_with_config (model_name= 'model1', folder_name = 'model1_single_train',labels = ['auc-pr', 'val_auc-pr'], ylims= [.5,1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\hcv-gt24-env\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'auc-pr'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plotting.multi_line_plot_history (model_name= 'model1', 
                                  folder_name = 'model1_batch8', 
                                  label = 'val_loss',
                                  hyperparameter = ['model_architecture', 'dropout_rate'],
                                #   ylims = [0.7,0.9],
                                  file_name_filter = r'.*_\da\..*',
                                  )
# Out:
# ['m1_b8_1a.yaml', 'm1_b8_2a.yaml', 'm1_b8_3a.yaml']

# %%
plotting.multi_line_plot_history (model_name= 'model1', 
                                  folder_name = 'model1_batch8', 
                                  label = 'val_auc-pr',
                                  hyperparameter = ['model_architecture', 'dropout_rate'],
                                #   ylims = [0.7,0.9],
                                  file_name_filter = r'.*_\da\..*',
                                  )
# Out:
# ['m1_b8_1a.yaml', 'm1_b8_2a.yaml', 'm1_b8_3a.yaml']
