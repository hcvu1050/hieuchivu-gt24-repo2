# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.batch_plot_loss (model_name= 'model1')
# Out:
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:73: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:73: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
plt.figure(figsize=(12,5)) 
plt.subplot(1, 2, 1)
plotting.plot_loss ('../reports/model1/train_loss/train_loss_model1_1.csv', title='plot1')
plt.subplot(1, 2, 2)
plotting.plot_config  ('../configs/model1_1.yaml', 'title')

# %%
plt.figure(figsize=(10, 5)) 
plt.subplot(1, 2, 1)
plotting.plot_loss ('../reports/model1/training_history_model1/training_history_model1_1.csv', title='plot1')
plt.subplot(1, 2, 2)
plotting.plot_config  ('../configs/model1_1.yaml', 'title')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\plot_test.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/notebooks/plot_test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(10, 5))
#       <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/notebooks/plot_test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> plt.subplot(1, 2, 1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/notebooks/plot_test.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> plotting.plot_loss ('../reports/model1/training_history_model1/training_history_model1_1.csv', title='plot1')
#       <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/notebooks/plot_test.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> plt.subplot(1, 2, 2)
# ...

# %%
plt.subplot(1, 2, 2)
plotting.plot_config  ('../configs/model1_1.yaml', 'title')
