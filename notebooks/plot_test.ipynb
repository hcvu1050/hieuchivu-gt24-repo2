# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.grid_plot_history_with_config (model_name= 'model1', folder_name = 'model1_batch7',labels = ['auc-pr', 'val_auc-pr'])
# Out:
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:105: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:105: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:105: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:105: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
plotting.multi_line_plot_history (model_name= 'model1', 
                                  folder_name = 'model1_batch7', 
                                  label = 'val_auc-pr',
                                  hyperparameter = ['model_architecture', 'group_nn_hidden_layer_depth'],
                                  )
