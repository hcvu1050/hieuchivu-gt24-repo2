# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.grid_plot_history_with_config (model_name= 'model1', folder_name = 'model1_single_train',labels = ['auc-pr', 'val_auc-pr'])
# Out:
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:113: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\plot_test.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vuchi/GT24/hieuchivu-gt24-repo2/notebooks/plot_test.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> plotting.grid_plot_history_with_config (model_name= 'model1', folder_name = 'model1_single_train',labels = ['auc-pr', 'val_auc-pr'])
#
# File c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:33, in grid_plot_history_with_config(model_name, folder_name, labels, file_name_filter, ylims, xlims)
#      30 plt.figure(figsize=(12, 5 * num_grid_rows))
#      32 for grid in range (1, len(history_file_list) + len(config_file_list)+1):
# ---> 33     plt.subplot (num_grid_rows, 2, grid)
#      35     if grid % 2 == 1:
#      36         if ylims is not None: plt.ylim(ylims)
#
# File c:\ProgramData\anaconda3\envs\hcv-gt24-env\Lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File c:\ProgramData\anaconda3\envs\hcv-gt24-env\Lib\site-packages\matplotlib\gridspec.py:600, in SubplotSpec._from_subplot_args(figure, args)
#     598 else:
#     599     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 600         raise ValueError(
#     601             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     602             f"not {num!r}"
#     603         )
#     604     i = j = num
#     605 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 4, not 5

# %%
plotting.multi_line_plot_history (model_name= 'model1', 
                                  folder_name = 'model1_batch8', 
                                  label = 'val_loss',
                                  hyperparameter = ['model_architecture', 'dropout_rate'],
                                #   ylims = [0.7,0.9],
                                  file_name_filter = r'.*_\da\..*',
                                  )
# Out:
# ['m1_b8_1a.yaml', 'm1_b8_2a.yaml', 'm1_b8_3a.yaml']

# %%
plotting.multi_line_plot_history (model_name= 'model1', 
                                  folder_name = 'model1_batch8', 
                                  label = 'val_auc-pr',
                                  hyperparameter = ['model_architecture', 'dropout_rate'],
                                #   ylims = [0.7,0.9],
                                  file_name_filter = r'.*_\da\..*',
                                  )
# Out:
# ['m1_b8_1a.yaml', 'm1_b8_2a.yaml', 'm1_b8_3a.yaml']
