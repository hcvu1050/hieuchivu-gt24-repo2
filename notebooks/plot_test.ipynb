# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.batch_plot_loss (model_name= 'model1', folder_name = 'model1_batch1')
# Out:
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ...

# %%
plotting.batch_plot_loss (model_name= 'model1', folder_name = 'model1_batch2')
# Out:
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:76: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
