# %%
import sys
sys.path.append('../src') 


import pandas as pd
import matplotlib.pyplot as plt

# %%
from visualization import plotting

# %%
plotting.grid_plot_history_with_config (model_name= 'model1', folder_name = 'model1_batch8',labels = ['auc-pr', 'val_auc-pr'], ylims= [.5,1])
# Out:
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:113: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:113: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:113: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:113: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:113: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\vuchi\GT24\hieuchivu-gt24-repo2\notebooks\../src\visualization\plotting.py:113: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ...

# %%
plotting.multi_line_plot_history (model_name= 'model1', 
                                  folder_name = 'model1_batch8', 
                                  label = 'val_auc-pr',
                                  hyperparameter = ['model_architecture', 'initializer'],
                                  ylims = [0.7,0.9],
                                  file_name_filter = r'.*_1c.*',
                                  )
# Out:
# ['m1_b8_1c.yaml', 'm1_b8_1c_he.yaml']
